# %% [markdown]
# # Projeto 1 - Ciência dos Dados #

# %% [markdown]
# **Matheus Amaral Ricardo**

# %% [markdown]
# **Pergunta**: O Protocolo de Kyoto foi criado visando a diminuição de gases estufa. Os países que estão dentro deste emitem mais gás carbônico que os que não estão no acordo? O PIB dos países reflete na emissão deste gás?

# %% [markdown]
# **Hipótese**: Países que emitiam maiores níveis de gás carbônico eram os mais ricos (com maior PIB per capita), logo assinaram o Protocolo de Kyoto visando a diminuição da emissão do gás. Ao longo dos anos os países dentro do protocolo diminuiriam sua emissão de gases estufa, enquanto os outros manteriam ou até aumentariam.
# https://revistas.pucsp.br/index.php/rpe/article/viewFile/11774/8496

# %% [markdown]
# **Base de dados utilizada**:
# https://data.worldbank.org/indicator/NY.GDP.PCAP.KD
# https://cdiac.ess-dive.lbl.gov/

# %%
import pandas as pd
import numpy as np
import math as math
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Leitura dos arquivos em Excel
co2 = pd.read_excel('co2_emissions_tonnes_per_person.xlsx')
pib = pd.read_excel('gdppercapita_us_inflation_adjusted.xlsx')

# %%
CO2 = co2.set_index("country")
CO2.columns
CO2_datas = [1970,1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979,1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988,1989, 1990, 1991, 1992, 1993, 1994, 1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014]
CO2_anos = CO2.loc[:, CO2_datas]
CO2_anos_t = CO2_anos.T
medias_CO2 = CO2_anos.mean()
plt.figure(figsize=(20,10))
for pais in CO2_anos_t.columns:
    plt.scatter(x=CO2_anos_t.index, y=CO2_anos_t[pais])
plt.plot(medias_CO2.index,  medias_CO2, color="r")

# %%
#Dados de 2000
co2_00 = co2.loc[:, ["country", 2000]]
pib_00 = pib.loc[:, ["country", 2000]]

# %%
#Trocando o índice das tabelas
co2_index = co2_00.set_index("country")
pib_index = pib_00.set_index("country")

# %%
#Removendo países sem dados
co2_nan = co2_index.dropna()
pib_nan = pib_index.dropna()

# %%
#Juntando as duas tabelas
co2_pib = co2_nan.join(pib_nan, how="inner", lsuffix="_CO2", rsuffix="_PIB")
co2_pib.columns = ['2000 CO2 Emissions (tones per person)', '2000 GDP per capita']
co2_pib
# Out:
#                                 2000 CO2 Emissions (tones per person)  \
# country
# Albania                                                        0.9680
# Algeria                                                        2.8200
# Andorra                                                        8.0200
# Angola                                                         0.5800
# Antigua and Barbuda                                            4.1200
# Argentina                                                      3.8400
# Armenia                                                        1.1300
# Australia                                                     17.3000
# Austria                                                        7.7200
# Azerbaijan                                                     3.6300
# Bahamas                                                        5.6000
# Bahrain                                                       28.1000
# Bangladesh                                                     0.2120
# Barbados                                                       4.4000
# Belarus                                                        5.4100
# Belgium                                                       11.2000
# Belize                                                         1.6000
# Benin                                                          0.2330
# Bhutan                                                         0.6910
# Bolivia                                                        1.3300
# Bosnia and Herzegovina                                         3.6600
# Botswana                                                       2.1900
# Brazil                                                         1.8700
# Brunei                                                        14.1000
# Bulgaria                                                       5.4400
# Burkina Faso                                                   0.0897
# Burundi                                                        0.0424
# Cambodia                                                       0.1630
# Cameroon                                                       0.2250
# Canada                                                        17.4000
# ...                                                               ...
# St. Lucia                                                      2.1000
# St. Vincent and the Grenadines                                 1.3600
# Sudan                                                          0.2030
# Suriname                                                       4.6500
# Swaziland                                                      1.1200
# Sweden                                                         5.5600
# Switzerland                                                    5.4500
# Tajikistan                                                     0.3600
# Tanzania                                                       0.0776
# Thailand                                                       2.8800
# Togo                                                           0.2740
# Tonga                                                          0.9720
# Trinidad and Tobago                                           18.8000
# Tunisia                                                        2.0500
# Turkey                                                         3.4200
# Turkmenistan                                                   8.3100
# Tuvalu                                                         0.7790
# Uganda                                                         0.0595
# Ukraine                                                        6.5700
# United Arab Emirates                                          35.7000
# United Kingdom                                                 9.1900
# United States                                                 20.2000
# Uruguay                                                        1.6000
# Uzbekistan                                                     4.9000
# Vanuatu                                                        0.4560
# Venezuela                                                      6.2200
# Vietnam                                                        0.6680
# Yemen                                                          0.8190
# Zambia                                                         0.1730
# Zimbabwe                                                       1.1400
#
#                                 2000 GDP per capita
# country
# Albania                                      2340.0
# Algeria                                      3540.0
# Andorra                                     40800.0
# Angola                                       1720.0
# Antigua and Barbuda                         12000.0
# Argentina                                    8180.0
# Armenia                                      1400.0
# Australia                                   44300.0
# Austria                                     42000.0
# Azerbaijan                                   1630.0
# Bahamas                                     31600.0
# Bahrain                                     23000.0
# Bangladesh                                    509.0
# Barbados                                    15000.0
# Belarus                                      2810.0
# Belgium                                     40200.0
# Belize                                       3840.0
# Benin                                         694.0
# Bhutan                                       1200.0
# Bolivia                                      1620.0
# Bosnia and Herzegovina                       3000.0
# Botswana                                     4950.0
# Brazil                                       8780.0
# Brunei                                      35900.0
# Bulgaria                                     3960.0
# Burkina Faso                                  435.0
# Burundi                                       228.0
# Cambodia                                      431.0
# Cameroon                                     1160.0
# Canada                                      43600.0
# ...                                             ...
# St. Lucia                                    7220.0
# St. Vincent and the Grenadines               4750.0
# Sudan                                        1000.0
# Suriname                                     5690.0
# Swaziland                                    2950.0
# Sweden                                      44700.0
# Switzerland                                 67800.0
# Tajikistan                                    414.0
# Tanzania                                      497.0
# Thailand                                     3460.0
# Togo                                          516.0
# Tonga                                        3280.0
# Trinidad and Tobago                          9780.0
# Tunisia                                      3000.0
# Turkey                                       8240.0
# Turkmenistan                                 2380.0
# Tuvalu                                       3080.0
# Uganda                                        412.0
# Ukraine                                      1820.0
# United Arab Emirates                        62800.0
# United Kingdom                              35600.0
# United States                               45100.0
# Uruguay                                      9000.0
# Uzbekistan                                    813.0
# Vanuatu                                      2840.0
# Venezuela                                   11800.0
# Vietnam                                       762.0
# Yemen                                        1140.0
# Zambia                                        938.0
# Zimbabwe                                     1260.0
#
# [182 rows x 2 columns]

# %%
#Mostrando na tabela os países que assinaram o Protocolo de Kyoto
kyoto = ['Antigua and Barbuda','Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Chile','China','Costa Rica','Croatia','Cuba','Czech Republic','Denmark','Ecuador','Egypt','El Salvador','Estonia','Fiji','Finland','France','Germany','Greece','Guatemala','Honduras','Indonesia','Ireland','Israel','Italy','Japan','Kazakhstan','South Korea','Latvia','Lithuania','Luxembourg','Malaysia','Maldives','Mali','Malta','Marshall Islands','Mexico','Micronesia, Fed. Sts.','Netherlands','New Zealand','Nicaragua','Niger','Norway','Panama','Papua New Guinea','Paraguay','Peru','Philippines','Poland','Portugal','Romania','Russia','St. Lucia','St. Vincent and the Grenadines','Samoa','Seychelles','Slovak Republic','Slovenia','Solomon Islands','Spain','Sweden','Switzerland','Thailand','Trinidad and Tobago','Turkmenistan','Tuvalu','Ukraine','United Kingdom','Uruguay','Uzbekistan','Vietnam','Zambia']
co2_pib.loc[:, "Kyoto Protocol"] = 0
co2_pib.loc[kyoto, "Kyoto Protocol"] = 1
co2_pib
# Out:
#                                 2000 CO2 Emissions (tones per person)  \
# country
# Albania                                                        0.9680
# Algeria                                                        2.8200
# Andorra                                                        8.0200
# Angola                                                         0.5800
# Antigua and Barbuda                                            4.1200
# Argentina                                                      3.8400
# Armenia                                                        1.1300
# Australia                                                     17.3000
# Austria                                                        7.7200
# Azerbaijan                                                     3.6300
# Bahamas                                                        5.6000
# Bahrain                                                       28.1000
# Bangladesh                                                     0.2120
# Barbados                                                       4.4000
# Belarus                                                        5.4100
# Belgium                                                       11.2000
# Belize                                                         1.6000
# Benin                                                          0.2330
# Bhutan                                                         0.6910
# Bolivia                                                        1.3300
# Bosnia and Herzegovina                                         3.6600
# Botswana                                                       2.1900
# Brazil                                                         1.8700
# Brunei                                                        14.1000
# Bulgaria                                                       5.4400
# Burkina Faso                                                   0.0897
# Burundi                                                        0.0424
# Cambodia                                                       0.1630
# Cameroon                                                       0.2250
# Canada                                                        17.4000
# ...                                                               ...
# St. Lucia                                                      2.1000
# St. Vincent and the Grenadines                                 1.3600
# Sudan                                                          0.2030
# Suriname                                                       4.6500
# Swaziland                                                      1.1200
# Sweden                                                         5.5600
# Switzerland                                                    5.4500
# Tajikistan                                                     0.3600
# Tanzania                                                       0.0776
# Thailand                                                       2.8800
# Togo                                                           0.2740
# Tonga                                                          0.9720
# Trinidad and Tobago                                           18.8000
# Tunisia                                                        2.0500
# Turkey                                                         3.4200
# Turkmenistan                                                   8.3100
# Tuvalu                                                         0.7790
# Uganda                                                         0.0595
# Ukraine                                                        6.5700
# United Arab Emirates                                          35.7000
# United Kingdom                                                 9.1900
# United States                                                 20.2000
# Uruguay                                                        1.6000
# Uzbekistan                                                     4.9000
# Vanuatu                                                        0.4560
# Venezuela                                                      6.2200
# Vietnam                                                        0.6680
# Yemen                                                          0.8190
# Zambia                                                         0.1730
# Zimbabwe                                                       1.1400
#
#                                 2000 GDP per capita  Kyoto Protocol
# country
# Albania                                      2340.0               0
# Algeria                                      3540.0               0
# Andorra                                     40800.0               0
# Angola                                       1720.0               0
# Antigua and Barbuda                         12000.0               1
# Argentina                                    8180.0               1
# Armenia                                      1400.0               0
# Australia                                   44300.0               1
# Austria                                     42000.0               1
# Azerbaijan                                   1630.0               0
# Bahamas                                     31600.0               0
# Bahrain                                     23000.0               0
# Bangladesh                                    509.0               0
# Barbados                                    15000.0               0
# Belarus                                      2810.0               0
# Belgium                                     40200.0               1
# Belize                                       3840.0               0
# Benin                                         694.0               0
# Bhutan                                       1200.0               0
# Bolivia                                      1620.0               0
# Bosnia and Herzegovina                       3000.0               0
# Botswana                                     4950.0               0
# Brazil                                       8780.0               1
# Brunei                                      35900.0               0
# Bulgaria                                     3960.0               1
# Burkina Faso                                  435.0               0
# Burundi                                       228.0               0
# Cambodia                                      431.0               0
# Cameroon                                     1160.0               0
# Canada                                      43600.0               0
# ...                                             ...             ...
# St. Lucia                                    7220.0               1
# St. Vincent and the Grenadines               4750.0               1
# Sudan                                        1000.0               0
# Suriname                                     5690.0               0
# Swaziland                                    2950.0               0
# Sweden                                      44700.0               1
# Switzerland                                 67800.0               1
# Tajikistan                                    414.0               0
# Tanzania                                      497.0               0
# Thailand                                     3460.0               1
# Togo                                          516.0               0
# Tonga                                        3280.0               0
# Trinidad and Tobago                          9780.0               1
# Tunisia                                      3000.0               0
# Turkey                                       8240.0               0
# Turkmenistan                                 2380.0               1
# Tuvalu                                       3080.0               1
# Uganda                                        412.0               0
# Ukraine                                      1820.0               1
# United Arab Emirates                        62800.0               0
# United Kingdom                              35600.0               1
# United States                               45100.0               0
# Uruguay                                      9000.0               1
# Uzbekistan                                    813.0               1
# Vanuatu                                      2840.0               0
# Venezuela                                   11800.0               0
# Vietnam                                       762.0               1
# Yemen                                        1140.0               0
# Zambia                                        938.0               1
# Zimbabwe                                     1260.0               0
#
# [182 rows x 3 columns]

# %%
#Tabela final separada por assinantes e não assinantes
co2_pib.sort_values('Kyoto Protocol', inplace = True)
co2_pib
# Out:
#                   2000 CO2 Emissions (tones per person)  2000 GDP per capita  \
# country
# Albania                                          0.9680               2340.0
# Mozambique                                       0.0747                257.0
# Morocco                                          1.1800               1970.0
# Montenegro                                       2.8400               4950.0
# Mongolia                                         3.1300               1600.0
# Moldova                                          0.8360                968.0
# Mauritius                                        2.2700               5560.0
# Mauritania                                       0.4330                998.0
# Malawi                                           0.0764                385.0
# Madagascar                                       0.1190                430.0
# Macedonia, FYR                                   5.9300               3450.0
# Libya                                            8.8000               8970.0
# Liberia                                          0.1460                392.0
# Lesotho                                          0.9910                880.0
# Myanmar                                          0.2190                347.0
# Lao                                              0.1760                672.0
# Kuwait                                          26.1000              35800.0
# Kiribati                                         0.3480               1730.0
# Kenya                                            0.3310                833.0
# Jordan                                           3.0400               2810.0
# Jamaica                                          3.8800               4640.0
# Iraq                                             3.0700               4310.0
# Iran                                             5.6300               4780.0
# India                                            0.9800                762.0
# Iceland                                          7.7100              36600.0
# Hungary                                          5.4600              10500.0
# Haiti                                            0.1600                767.0
# Guyana                                           2.1400               2350.0
# Guinea-Bissau                                    0.1180                532.0
# Kyrgyz Republic                                  0.9420                654.0
# ...                                                 ...                  ...
# Lithuania                                        3.4700               6930.0
# Marshall Islands                                 1.4800               2620.0
# Malta                                            5.2000              18300.0
# Mali                                             0.0749                554.0
# Maldives                                         1.6100               5780.0
# Malaysia                                         5.4200               7010.0
# Croatia                                          4.3700              10600.0
# Costa Rica                                       1.3900               6230.0
# New Zealand                                      8.5500              29000.0
# Nicaragua                                        0.7480               1310.0
# Niger                                            0.0614                322.0
# Samoa                                            0.8190               2770.0
# Bulgaria                                         5.4400               3960.0
# Denmark                                                  9.6100
# Oman                                                     9.6500
# Israel                                                  10.0000
# Finland                                                 10.1000
# Germany                                                 10.2000
# Russia                                                  10.6000
# Estonia                                                 10.6000
# Ireland                                                 10.7000
# Netherlands                                             10.9000
# Belgium                                                 11.2000
# Czech Republic                                          12.0000
# Singapore                                               12.5000
# Palau                                                   13.0000
# Brunei                                                  14.1000
# Saudi Arabia                                            14.3000
# Australia                                               17.3000
# Canada                                                  17.4000
# Trinidad and Tobago                                     18.8000
# Luxembourg                                              18.9000
# United States                                           20.2000
# Kuwait                                                  26.1000
# Bahrain                                                 28.1000
# United Arab Emirates                                    35.7000
# Qatar                                                   58.6000
#
#                           2000 GDP per capita  Kyoto Protocol
# country
# Congo, Dem. Rep.                        290.0               0
# Chad                                    463.0               0
# Burundi                                 228.0               0
# Ethiopia                                197.0               0
# Uganda                                  412.0               0
# Niger                                   322.0               1
# Rwanda                                  327.0               0
# Central African Republic                412.0               0
# Mozambique                              257.0               0
# Mali                                    554.0               1
# Malawi                                  385.0               0
# Tanzania                                497.0               0
# Burkina Faso                            435.0               0
# Sierra Leone                            304.0               0
# Guinea-Bissau                           532.0               0
# Madagascar                              430.0               0
# Nepal                                   459.0               0
# Liberia                                 392.0               0
# Haiti                                   767.0               0
# Cambodia                                431.0               0
# Zambia                                  938.0               1
# Lao                                     672.0               0
# Eritrea                                 572.0               0
# Guinea                                  585.0               0
# Comoros                                 806.0               0
# Gambia                                  530.0               0
# Sudan                                  1000.0               0
# Bangladesh                              509.0               0
# Myanmar                                 347.0               0
# Cameroon                               1160.0               0
# ...                                       ...             ...
# New Zealand                           29000.0               1
# Libya                                  8970.0               0
# Norway                                81700.0               1
# United Kingdom                        35600.0               1
# South Korea                           15100.0               1
# Japan                                 42200.0               1
# Denmark                               55900.0               1
# Oman                                  18700.0               0
# Israel                                27600.0               1
# Finland                               40500.0               1
# Germany                               38000.0               1
# Russia                                 6490.0               1
# Estonia                               10100.0               1
# Ireland                               42900.0               1
# Netherlands                           46100.0               1
# Belgium                               40200.0               1
# Czech Republic                        14800.0               1
# Singapore                             33400.0               0
# Palau                                  9340.0               0
# Brunei                                35900.0               0
# Saudi Arabia                          18300.0               0
# Australia                             44300.0               1
# Canada                                43600.0               0
# Trinidad and Tobago                    9780.0               1
# Luxembourg                            93500.0               1
# United States                         45100.0               0
# Kuwait                                35800.0               0
# Bahrain                               23000.0               0
# United Arab Emirates                  62800.0               0
# Qatar                                 60900.0               0
#
# [182 rows x 3 columns]

# %%
#Tabela final ordenada pelo PIB per capita
co2_pib.sort_values('2000 GDP per capita', inplace = True)
co2_pib
# Out:
#                           2000 CO2 Emissions (tones per person)  \
# country
# Ethiopia                                                 0.0534
# Burundi                                                  0.0424
# Mozambique                                               0.0747
# Congo, Dem. Rep.                                         0.0173
# Sierra Leone                                             0.0932
# Niger                                                    0.0614
# Rwanda                                                   0.0658
# Myanmar                                                  0.2190
# Malawi                                                   0.0764
# Liberia                                                  0.1460
# Uganda                                                   0.0595
# Central African Republic                                 0.0713
# Tajikistan                                               0.3600
# Luxembourg                            93500.0               1
#
# [182 rows x 3 columns]

# %%
co2_pib.plot.scatter(x='2000 CO2 Emissions (tones per person)',y='2000 GDP per capita', logy=True)
sns.regplot(co2_pib['2000 CO2 Emissions (tones per person)'],co2_pib['2000 GDP per capita'], color=('indigo'))
plt.grid()

# %%
co2_pib['2000 CO2 Emissions (tones per person)'].corr(co2_pib['2000 GDP per capita'])
# Out:
# 0.6895169227026365

# %%
sim = co2_pib.loc[kyoto,:]

# %%
sim.plot.scatter(x='2000 CO2 Emissions (tones per person)',y='2000 GDP per capita', logy=True)
sns.regplot(sim['2000 CO2 Emissions (tones per person)'],sim['2000 GDP per capita'], color=('green'))
plt.grid()

# %%
sim['2000 CO2 Emissions (tones per person)'].corr(sim['2000 GDP per capita'])
# Out:
# 0.6644652183316472

# %% [markdown]
# Os países com menor PIB per capita emitem menos gás carbônico que países com PIB per capita maior, de modo que no topo das duas tabelas finais se encontram países, em sua maioria, fora do protocolo e com PIB per capita e emissão de gás carbônico baixa, enquanto no final delas, ocorre o oposto. Portanto, países que assinaram o protocolo emitiam mais CO2 e tinham PIB per capita maior.

# %%
co2_pib.loc[:, "Kyoto Protocol"] = 'não'
nao = co2_pib

# %%
nao.plot.scatter(x='2000 CO2 Emissions (tones per person)',y='2000 GDP per capita', logy=True)
sns.regplot(nao['2000 CO2 Emissions (tones per person)'],nao['2000 GDP per capita'], color=('red'))
plt.grid()

# %%
nao['2000 CO2 Emissions (tones per person)'].corr(nao['2000 GDP per capita'])
# Out:
# 0.6895169227026365

# %%
plt.scatter(co2.loc[co2.kyoto == 0,"2000"], pib.loc[pib.kyoto == 0,"2000"], color="r")
plt.scatter(co2.loc[co2.kyoto == 1,"2000"], pib.loc[pib.kyoto == 1,"2000"], color="b")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-238-3eb2b036aea4> in <module>
# ----> 1 plt.scatter(co2.loc[co2.kyoto == 0,"2000"], pib.loc[pib.kyoto == 0,"2000"], color="r")
#       2 plt.scatter(co2.loc[co2.kyoto == 1,"2000"], pib.loc[pib.kyoto == 1,"2000"], color="b")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'kyoto'

# %%
#Leitura dos arquivos em Excel
co2 = pd.read_excel('co2_emissions_tonnes_per_person.xlsx')
pib = pd.read_excel('gdppercapita_us_inflation_adjusted.xlsx')

#Dados de 20
co2_07 = co2.loc[:, ["country", 2007]]
pib_07 = pib.loc[:, ["country", 2007]]

#Trocando o índice das tabelas
co2_index = co2_07.set_index("country")
pib_index = pib_07.set_index("country")

#Removendo países sem dados
co2_nan = co2_index.dropna()
pib_nan = pib_index.dropna()

#Juntando as duas tabelas
co2_pib = co2_nan.join(pib_nan, how="inner", lsuffix="_CO2", rsuffix="_PIB")
co2_pib.columns = ['2007 CO2 Emissions (tones per person)', '2007 GDP per capita']

#Mostrando na tabela os países que assinaram o Protocolo de Kyoto
co2_pib.loc[:, "Kyoto Protocol"] = 0
co2_pib.loc[kyoto, "Kyoto Protocol"] = 1

# %%
co2_pib.plot.scatter(x='2007 CO2 Emissions (tones per person)',y='2007 GDP per capita', logy=True)
sns.regplot(co2_pib['2007 CO2 Emissions (tones per person)'],co2_pib['2007 GDP per capita'], color=('indigo'))
plt.grid()
co2_pib['2007 CO2 Emissions (tones per person)'].corr(co2_pib['2007 GDP per capita'])
# Out:
# 0.6494183474914059

# %%
sim = co2_pib.loc[kyoto,:]
sim.plot.scatter(x='2007 CO2 Emissions (tones per person)',y='2007 GDP per capita', logy=True)
sns.regplot(sim['2007 CO2 Emissions (tones per person)'],sim['2007 GDP per capita'], color=('green'))
plt.grid()
sim['2007 CO2 Emissions (tones per person)'].corr(sim['2007 GDP per capita'])
# Out:
# 0.549605781795617

# %%
co2_pib.loc[:, "Kyoto Protocol"] = 0
nao = co2_pib
nao.plot.scatter(x='2007 CO2 Emissions (tones per person)',y='2007 GDP per capita', logy=True)
sns.regplot(nao['2007 CO2 Emissions (tones per person)'],nao['2007 GDP per capita'], color=('red'))
plt.grid()
nao['2007 CO2 Emissions (tones per person)'].corr(nao['2007 GDP per capita'])
# Out:
# 0.6494183474914059

# %%
#Leitura dos arquivos em Excel
co2 = pd.read_excel('co2_emissions_tonnes_per_person.xlsx')
pib = pd.read_excel('gdppercapita_us_inflation_adjusted.xlsx')

#Dados de 20
co2_14 = co2.loc[:, ["country", 2014]]
pib_14 = pib.loc[:, ["country", 2014]]

#Trocando o índice das tabelas
co2_index = co2_14.set_index("country")
pib_index = pib_14.set_index("country")

#Removendo países sem dados
co2_nan = co2_index.dropna()
pib_nan = pib_index.dropna()

#Juntando as duas tabelas
co2_pib = co2_nan.join(pib_nan, how="inner", lsuffix="_CO2", rsuffix="_PIB")
co2_pib.columns = ['2014 CO2 Emissions (tones per person)', '2014 GDP per capita']

#Mostrando na tabela os países que assinaram o Protocolo de Kyoto
co2_pib.loc[:, "Kyoto Protocol"] = 0
co2_pib.loc[kyoto, "Kyoto Protocol"] = 1

# %%
co2_pib.plot.scatter(x='2014 CO2 Emissions (tones per person)',y='2014 GDP per capita', logy=True)
sns.regplot(co2_pib['2014 CO2 Emissions (tones per person)'],co2_pib['2014 GDP per capita'], color=('indigo'))
plt.grid()
co2_pib['2014 CO2 Emissions (tones per person)'].corr(co2_pib['2014 GDP per capita'])
# Out:
# 0.594080145783105

# %%
sim = co2_pib.loc[kyoto,:]
sim.plot.scatter(x='2014 CO2 Emissions (tones per person)',y='2014 GDP per capita', logy=True)
sns.regplot(sim['2014 CO2 Emissions (tones per person)'],sim['2014 GDP per capita'], color=('green'))
plt.grid()
sim['2014 CO2 Emissions (tones per person)'].corr(sim['2014 GDP per capita'])
# Out:
# 0.4463882434195381

# %%
co2_pib.loc[:, "Kyoto Protocol"] = 0
nao = co2_pib
nao.plot.scatter(x='2014 CO2 Emissions (tones per person)',y='2014 GDP per capita', logy=True)
sns.regplot(nao['2014 CO2 Emissions (tones per person)'],nao['2014 GDP per capita'], color=('red'))
plt.grid()
nao['2014 CO2 Emissions (tones per person)'].corr(nao['2014 GDP per capita'])
# Out:
# 0.594080145783105

# %%
y = energia.mean()
x = y.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-237-c73ed106c820> in <module>
# ----> 1 y = energia.mean()
#       2 x = y.index
#
# NameError: name 'energia' is not defined
